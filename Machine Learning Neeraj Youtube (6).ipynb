# %%
#import the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
from sklearn.model_selection import train_test_split

# %%
#import data file
df= pd.read_table('C:\\Users\\Neera\\OneDrive\\Desktop\\fruit_data_with_colors.txt')

# %%
#check out the data descriptives
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
#we define x and y
y= df['fruit_label']
x=df[['mass'	,'width',	'height'	,'color_score']]

# %%
#split the data 75/25 per cent 

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
#normalisation of data
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
x_train_scaler= scaler.fit_transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
#creating the model
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors= 5)

# %%
#fit the model
knn.fit(x_train_scaler,y_train)
# Out:
# KNeighborsClassifier()

# %%
#accuracy of the model
knn.score(x_train_scaler,y_train)
# Out:
# 0.9545454545454546

# %%
#accuracy of the model
knn.score(x_test_scaler,y_test)
# Out:
# 1.0

# %%
find_the_fruit= dict(zip(df.fruit_label.unique(),df.fruit_name.unique()))
find_the_fruit
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon'}

# %%
#prediction from the model
scaled_input= scaler.transform([[186,	7.2	,9.2	,0.72]])
scaled_input
pred=knn.predict(scaled_input)
name=find_the_fruit [pred[0]]
name
# Out:
# C:\Users\Neera\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 'lemon'
